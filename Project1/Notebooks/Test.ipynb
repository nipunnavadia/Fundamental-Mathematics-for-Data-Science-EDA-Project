# %% [markdown]
# # <Center> Computer Science Department
# ## <Center> CS660 – Mathematical Foundations of Analytics (CRN# 22921)
# ### <Center>Spring 2025
# #### <Center>Project #1 / Due 27-Feb-2025
# #### <Center>Exploratory Data Analysis (EDA) is a crucial step in any data science or machine learning project. It serves multiple purposes:

# %% [markdown]
# ##### 1. Understanding the Data: EDA helps in getting a better understanding of the data, including its distribution, relationships, and patterns. It allows you to get a sense of the data's underlying structure, which is essential for making informed decisions in later stages.
# ##### 2. Data Cleaning: Through EDA, you can identify missing values, outliers, and inconsistencies in the data. Addressing these issues early on ensures the quality and reliability of the data.
# ##### 3. Hypothesis Generation: EDA helps in generating hypotheses about the data. By visually exploring the data, you can identify potential relationships and correlations that may not be immediately obvious.
# ##### 4. Feature Selection and Engineering: EDA aids in selecting the most relevant features and engineering new ones that could improve model performance. It helps in understanding which variables have the most predictive power.
# ##### 5. Model Selection: Understanding the data through EDA allows you to choose the most appropriate algorithms for your problem. For instance, if your data is not linearly separable, you might consider non-linear models.
# ##### 6. Risk Mitigation: EDA helps in identifying potential pitfalls and risks, such as data leakage or biased data, that could impact the model's performance.

# %% [markdown]
# Data Source: Electric Vehicle Population Data in Washington State, USA, available at
# https://data.gov/
# Data Name: EV_Population_WA_Data.csv (already uploaded into the portal)
# Data Description: This CSV file contains 200,048 rows, each representing an electric
# vehicle. The dataset includes the following columns: VIN, County, City, State, Postal
# Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle
# (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID,
# Vehicle Location, Electric Utility, and 2020 Census Tract.

# %% [markdown]
# ### For this data analysis project, we'll be using the following dataset:
# Data Source: Electric Vehicle Population Data in Washington State, USA, available at
# https://data.gov/
# Data Name: EV_Population_WA_Data.csv (already uploaded into the portal)
# Data Description: This CSV file contains 200,048 rows, each representing an electric
# vehicle. The dataset includes the following columns: VIN, County, City, State, Postal
# Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle
# (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID,
# Vehicle Location, Electric Utility, and 2020 Census Tract.

# %% [markdown]
# ### Project Purpose:
# The goal of this project is to create a Notebook (Jupyter, Colab) and become familiar
# with the Pandas and Matplotlib/Seaborn/Plotly libraries.
# Questions to be Answered:
# 1. Which car <b>manufacturers</b> are the most commonly used for EVs in Washington?
# 2. What are the <b>highest and lowest electric ranges</b> in this dataset, and which car
# <b>makers and models</b> do they correspond to?
# 3. Is the <b>maximum electric range </b>value unique? If not, which cars share this range?
# 4. Is the <b>minimum electric range</b> value unique? If not, which cars share this range?
# 5. How does the <b>electric</b> range vary <b>between car makers and between models</b>?
# 6. Which are the top <b>5 cities</b> adopting EVs?
# 7. How does the EV adoption rate vary among car makers over the years?
# 8. Is there a correlation between the <b>electric range</b> and the <b>city </b>of an EV?
# 9. Which <b>county has the greatest</b> variety of <b> EV car models</b>?

# %% [markdown]
# ## Step 1
# ## Understand the Dataset Context

# %% [markdown]
# ### Step 1.1
# Objective Clarification: Define the purpose of the analysis and the questions you aim to answer.

# %% [markdown]
# The purpose of this analysis is to gain crucial insights of the Electric Vehicle Poplulation in Washington using Exploratory Data Analysis.
# <br>Our aim will be to answer the following questions:
# 1. Which car <b>manufacturers</b> are the most commonly used for EVs in Washington?
# 2. What are the <b>highest and lowest electric ranges</b> in this dataset, and which car
# <b>makers and models</b> do they correspond to?
# 3. Is the <b>maximum electric range </b>value unique? If not, which cars share this range?
# 4. Is the <b>minimum electric range</b> value unique? If not, which cars share this range?
# 5. How does the <b>electric</b> range vary <b>between car makers and between models</b>?
# 6. Which are the top <b>5 cities</b> adopting EVs?
# 7. How does the EV adoption rate vary among car makers over the years?
# 8. Is there a correlation between the <b>electric range</b> and the <b>city </b>of an EV?
# 9. Which <b>county has the greatest</b> variety of <b> EV car models</b>?

# %% [markdown]
# ### Step 1.2
# Data Source Identification: Determine the source of the data, its collection methods, and any relevant background information.

# %% [markdown]
# ### Electric Vehicle Population Data in Washington State, USA (Dataset)
# <br>Publisher: data.wa.gov
# <br>Maintainer: Department of Licensing
# <br>Source URL: https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
# <br>Category: Transportation
# <br>Public Access Leve: Public
# <br>This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
# <br>This CSV file contains 200,048 rows, each representing an electric vehicle.
# <br>The dataset includes the following columns: VIN, County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, and 2020 Census Tract.

# %% [markdown]
# ## Step 2
# ## Import Libraries and Load Data

# %% [markdown]
# ### Step 2.1
# Import Necessary Libraries: Load libraries such as pandas, numpy, matplotlib, seaborn, etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder
from scipy.stats import zscore

# %% [markdown]
# ### Step 2.2
# Load the Dataset: Load the dataset into a DataFrame using pandas (assume using Python).

# %%
#source_url="https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"
df=pd.read_csv("../Data/EV_Population_WA_Data.csv")

# %%
df['Model'].value_counts().Sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jh/r0k5kntd0nzgw4m5nxb7jncr0000gn/T/ipykernel_13631/1574639918.py in ?()
# ----> 1 df['Model'].value_counts().Sum()
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Sum'

# %%
df
# Out:
#         VIN (1-10)     County               City State  Postal Code  \
# 0       5YJ3E1EB0J   Thurston            Olympia    WA      98512.0
# 1       WA1AAAGE9M     Kitsap       Port Orchard    WA      98367.0
# 2       5YJ3E1EA2J     Yakima             Yakima    WA      98902.0
# 3       5YJ3E1EA4N     Yakima             Yakima    WA      98902.0
# 4       7SAYGAEE2P  Snohomish            Bothell    WA      98012.0
# ...            ...        ...                ...   ...          ...
# 200043  JTMAB3FVXR  Snohomish          Snohomish    WA      98290.0
# 200044  7FCTGAAA7P     Pierce             Orting    WA      98360.0
# 200045  1V2GNPE87P    Spokane            Spokane    WA      99201.0
# 200046  1G1RD6E42E  Snohomish  Mountlake Terrace    WA      98043.0
# 200047  5YJ3E1EAXP     Kitsap          Bremerton    WA      98311.0
#
#         Model Year        Make       Model  \
# 0             2018       TESLA     MODEL 3
# 1             2021        AUDI      E-TRON
# 2             2018       TESLA     MODEL 3
# 3             2022       TESLA     MODEL 3
# 4             2023       TESLA     MODEL Y
# ...            ...         ...         ...
# 200043        2024      TOYOTA  RAV4 PRIME
# 200044        2023      RIVIAN         R1T
# 200045        2023  VOLKSWAGEN        ID.4
# 200046        2014   CHEVROLET        VOLT
# 200047        2023       TESLA     MODEL 3
#
#                          Electric Vehicle Type  \
# 0               Battery Electric Vehicle (BEV)
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3               Battery Electric Vehicle (BEV)
# 4               Battery Electric Vehicle (BEV)
# ...                                        ...
# 200043  Plug-in Hybrid Electric Vehicle (PHEV)
# 200044          Battery Electric Vehicle (BEV)
# 200045          Battery Electric Vehicle (BEV)
# 200046  Plug-in Hybrid Electric Vehicle (PHEV)
# 200047          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             215
# 1                 Clean Alternative Fuel Vehicle Eligible             222
# 2                 Clean Alternative Fuel Vehicle Eligible             215
# 3       Eligibility unknown as battery range has not b...               0
# 4       Eligibility unknown as battery range has not b...               0
# ...                                                   ...             ...
# 200043            Clean Alternative Fuel Vehicle Eligible              42
# 200044  Eligibility unknown as battery range has not b...               0
# 200045  Eligibility unknown as battery range has not b...               0
# 200046            Clean Alternative Fuel Vehicle Eligible              38
# 200047  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  35.0       104823078
# 1               0                  35.0       156660507
# 2               0                  14.0       269374108
# 3               0                  15.0       213383894
# 4               0                   1.0       229496046
# ...           ...                   ...             ...
# 200043          0                  44.0       262809249
# 200044          0                   2.0       252195450
# 200045          0                   3.0       227314790
# 200046          0                  32.0       170747377
# 200047          0                  23.0       224663134
#
#                        Vehicle Location  \
# 0         POINT (-122.957046 46.991391)
# 1       POINT (-122.6530052 47.4739066)
# 2          POINT (-120.530331 46.59534)
# 3          POINT (-120.530331 46.59534)
# 4         POINT (-122.206146 47.839957)
# ...                                 ...
# 200043  POINT (-122.0483457 47.9435765)
# 200044   POINT (-122.197791 47.0948565)
# 200045    POINT (-117.428902 47.658268)
# 200046    POINT (-122.306706 47.792043)
# 200047     POINT (-122.636245 47.62806)
#
#                                      Electric Utility  2020 Census Tract
# 0                              PUGET SOUND ENERGY INC       5.306701e+10
# 1                              PUGET SOUND ENERGY INC       5.303509e+10
# 2                                          PACIFICORP       5.307700e+10
# 3                                          PACIFICORP       5.307700e+10
# 4                              PUGET SOUND ENERGY INC       5.306105e+10
# ...                                               ...                ...
# 200043                         PUGET SOUND ENERGY INC       5.306105e+10
# 200044  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 200045                  MODERN ELECTRIC WATER COMPANY       5.306300e+10
# 200046                         PUGET SOUND ENERGY INC       5.306105e+10
# 200047                         PUGET SOUND ENERGY INC       5.303509e+10
#
# [200048 rows x 17 columns]

# %% [markdown]
# ## Step 3
# ## Initial Data Inspection

# %% [markdown]
# ### Step 3.1
# View Data Structure: Use functions like .head(), .tail(), .info(), and .describe() to get a sense of the data structure, types, and summary statistics.

# %%
[df.columns]
# Out:
# [Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#         'Make', 'Model', 'Electric Vehicle Type',
#         'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#         'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#         'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#        dtype='object')]

# %%
df.head()
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EB0J   Thurston       Olympia    WA      98512.0        2018  TESLA
# 1  WA1AAAGE9M     Kitsap  Port Orchard    WA      98367.0        2021   AUDI
# 2  5YJ3E1EA2J     Yakima        Yakima    WA      98902.0        2018  TESLA
# 3  5YJ3E1EA4N     Yakima        Yakima    WA      98902.0        2022  TESLA
# 4  7SAYGAEE2P  Snohomish       Bothell    WA      98012.0        2023  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1   E-TRON  Battery Electric Vehicle (BEV)
# 2  MODEL 3  Battery Electric Vehicle (BEV)
# 3  MODEL 3  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             215
# 1            Clean Alternative Fuel Vehicle Eligible             222
# 2            Clean Alternative Fuel Vehicle Eligible             215
# 3  Eligibility unknown as battery range has not b...               0
# 4  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  35.0       104823078
# 1          0                  35.0       156660507
# 2          0                  14.0       269374108
# 3          0                  15.0       213383894
# 4          0                   1.0       229496046
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0    POINT (-122.957046 46.991391)  PUGET SOUND ENERGY INC       5.306701e+10
# 1  POINT (-122.6530052 47.4739066)  PUGET SOUND ENERGY INC       5.303509e+10
# 2     POINT (-120.530331 46.59534)              PACIFICORP       5.307700e+10
# 3     POINT (-120.530331 46.59534)              PACIFICORP       5.307700e+10
# 4    POINT (-122.206146 47.839957)  PUGET SOUND ENERGY INC       5.306105e+10

# %%
df.tail()
# Out:
#         VIN (1-10)     County               City State  Postal Code  \
# 200043  JTMAB3FVXR  Snohomish          Snohomish    WA      98290.0
# 200044  7FCTGAAA7P     Pierce             Orting    WA      98360.0
# 200045  1V2GNPE87P    Spokane            Spokane    WA      99201.0
# 200046  1G1RD6E42E  Snohomish  Mountlake Terrace    WA      98043.0
# 200047  5YJ3E1EAXP     Kitsap          Bremerton    WA      98311.0
#
#         Model Year        Make       Model  \
# 200043        2024      TOYOTA  RAV4 PRIME
# 200044        2023      RIVIAN         R1T
# 200045        2023  VOLKSWAGEN        ID.4
# 200046        2014   CHEVROLET        VOLT
# 200047        2023       TESLA     MODEL 3
#
#                          Electric Vehicle Type  \
# 200043  Plug-in Hybrid Electric Vehicle (PHEV)
# 200044          Battery Electric Vehicle (BEV)
# 200045          Battery Electric Vehicle (BEV)
# 200046  Plug-in Hybrid Electric Vehicle (PHEV)
# 200047          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 200043            Clean Alternative Fuel Vehicle Eligible              42
# 200044  Eligibility unknown as battery range has not b...               0
# 200045  Eligibility unknown as battery range has not b...               0
# 200046            Clean Alternative Fuel Vehicle Eligible              38
# 200047  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 200043          0                  44.0       262809249
# 200044          0                   2.0       252195450
# 200045          0                   3.0       227314790
# 200046          0                  32.0       170747377
# 200047          0                  23.0       224663134
#
#                        Vehicle Location  \
# 200043  POINT (-122.0483457 47.9435765)
# 200044   POINT (-122.197791 47.0948565)
# 200045    POINT (-117.428902 47.658268)
# 200046    POINT (-122.306706 47.792043)
# 200047     POINT (-122.636245 47.62806)
#
#                                      Electric Utility  2020 Census Tract
# 200043                         PUGET SOUND ENERGY INC       5.306105e+10
# 200044  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 200045                  MODERN ELECTRIC WATER COMPANY       5.306300e+10
# 200046                         PUGET SOUND ENERGY INC       5.306105e+10
# 200047                         PUGET SOUND ENERGY INC       5.303509e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200048 entries, 0 to 200047
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         200048 non-null  object
#  1   County                                             200044 non-null  object
#  2   City                                               200044 non-null  object
#  3   State                                              200048 non-null  object
#  4   Postal Code                                        200044 non-null  float64
#  5   Model Year                                         200048 non-null  int64
#  6   Make                                               200048 non-null  object
#  7   Model                                              200048 non-null  object
#  8   Electric Vehicle Type                              200048 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  200048 non-null  object
#  10  Electric Range                                     200048 non-null  int64
#  11  Base MSRP                                          200048 non-null  int64
#  12  Legislative District                               199606 non-null  float64
#  13  DOL Vehicle ID                                     200048 non-null  int64
#  14  Vehicle Location                                   200040 non-null  object
#  15  Electric Utility                                   200044 non-null  object
#  16  2020 Census Tract                                  200044 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 25.9+ MB

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  200044.000000  200048.000000   200048.000000  200048.000000
# mean    98176.178121    2020.871261       53.485279     947.551913
# std      2424.207811       2.994933       88.786301    7860.591091
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98372.000000    2023.000000       53.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         199606.000000    2.000480e+05       2.000440e+05
# mean              28.986063    2.262988e+08       5.297545e+10
# std               14.908108    7.282433e+07       1.605628e+09
# min                1.000000    4.385000e+03       1.001020e+09
# 25%               17.000000    1.904573e+08       5.303301e+10
# 50%               33.000000    2.363396e+08       5.303303e+10
# 75%               42.000000    2.609659e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.602100e+10

# %% [markdown]
# ### Step 3.2
# Check Dimensions: Identify the number of rows and columns using .shape().

# %%
sp=df.shape
print(f"Number of Rows = {sp[0]} \nNumber of Columns = {sp[1]}")
# Out:
# Number of Rows = 200048
# Number of Columns = 17

# %% [markdown]
# ### Step 3.3
# Identify Missing Values: Use .isnull().sum() to check for missing values.

# %%
missing_vals=df.isnull().sum()
missing_vals
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 442
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# 2020 Census Tract                                      4
# dtype: int64

# %%
columns_df=df.columns
plt.figure(figsize=(20,10))
plt.bar(columns_df, missing_vals)
plt.title("Number of missing values to columns", fontsize=30)
plt.ylabel("Number of missing vales",fontsize=20)
plt.xlabel("Name of Column\Feature",fontsize=20)
plt.xticks(columns_df, rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=columns_df, y=missing_vals)
plt.xticks(rotation=90)
for i, value in enumerate(missing_vals):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom', fontsize=10)
plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(10,6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xticks
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 for col in df.columns:
#       2     plt.figure(figsize=(10,6))
# ----> 3     sns.histplot(df[col], kde=True)
#       4     plt.title(f'Distribution of {col}')
#       5     plt.xticks
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
#    1436         shrink=shrink,
#    1437         common_norm=common_norm,
#    1438         common_bins=common_bins,
#    1439         kde=kde,
#    1440         kde_kws=kde_kws,
#    1441         color=color,
#    1442         legend=legend,
#    1443         estimate_kws=estimate_kws,
#    1444         line_kws=line_kws,
#    1445         **kwargs,
#    1446     )
#    1448 else:
#    1450     p.plot_bivariate_histogram(
#    1451         common_bins=common_bins,
#    1452         common_norm=common_norm,
#    (...)
#    1462         **kwargs,
#    1463     )
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\seaborn\distributions.py:729, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     727 if self.data_variable == "y":
#     728     default_x = estimator.stat.capitalize()
# --> 729 self._add_axis_labels(ax, default_x, default_y)
#     731 # Legend for semantic variables
#     732 if "hue" in self.variables and legend:
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1328, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1323 # TODO ax could default to None and use attached axes if present
#    1324 # but what to do about the case of facets? Currently using FacetGrid's
#    1325 # set_axis_labels method, which doesn't add labels to the interior even
#    1326 # when the axes are not shared. Maybe that makes sense?
#    1327 if not ax.get_xlabel():
# -> 1328     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1329     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1330 if not ax.get_ylabel():
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axis.py:1456, in Axis.get_ticklabels(self, minor, which)
#    1454 if minor:
#    1455     return self.get_minorticklabels()
# -> 1456 return self.get_majorticklabels()
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axis.py:1413, in Axis.get_majorticklabels(self)
#    1411 def get_majorticklabels(self):
#    1412     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1413     self._update_ticks()
#    1414     ticks = self.get_major_ticks()
#    1415     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axis.py:1264, in Axis._update_ticks(self)
#    1262 major_locs = self.get_majorticklocs()
#    1263 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264 major_ticks = self.get_major_ticks(len(major_locs))
#    1265 self.major.formatter.set_locs(major_locs)
#    1266 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axis.py:1604, in Axis.get_major_ticks(self, numticks)
#    1602     tick = self._get_tick(major=True)
#    1603     self.majorTicks.append(tick)
# -> 1604     self._copy_tick_props(self.majorTicks[0], tick)
#    1606 return self.majorTicks[:numticks]
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\axis.py:1571, in Axis._copy_tick_props(self, src, dest)
#    1569 dest.label1.update_from(src.label1)
#    1570 dest.label2.update_from(src.label2)
# -> 1571 dest.tick1line.update_from(src.tick1line)
#    1572 dest.tick2line.update_from(src.tick2line)
#    1573 dest.gridline.update_from(src.gridline)
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\lines.py:1354, in Line2D.update_from(self, other)
#    1351 self._solidjoinstyle = other._solidjoinstyle
#    1353 self._linestyle = other._linestyle
# -> 1354 self._marker = MarkerStyle(marker=other._marker)
#    1355 self._drawstyle = other._drawstyle
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File c:\Users\ranro\anaconda3\Lib\site-packages\matplotlib\markers.py:355, in MarkerStyle._set_marker(self, marker)
#     352     self._marker_function = getattr(
#     353         self, '_set_' + self.markers[marker])
#     354 elif isinstance(marker, MarkerStyle):
# --> 355     self.__dict__ = copy.deepcopy(marker.__dict__)
#     357 else:
#     358     try:
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File c:\Users\ranro\anaconda3\Lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Step 4
# ## Data Cleaning
# ### Step 4.1
# ### Handle Missing Data:
# Impute Missing Values: Fill missing values using strategies like mean, median, or mode imputation, or domain-specific methods.
# <br>Remove Missing Values: Drop rows or columns with missing data if appropriate.

# %%
df.isnull().sum().sort_values(ascending=False)
# Targeting the Columns having 4 null values.
# Out:
# Legislative District                                 442
# Vehicle Location                                       8
# 2020 Census Tract                                      4
# City                                                   4
# Electric Utility                                       4
# Postal Code                                            4
# County                                                 4
# Electric Range                                         0
# DOL Vehicle ID                                         0
# Base MSRP                                              0
# VIN (1-10)                                             0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Model                                                  0
# Make                                                   0
# Model Year                                             0
# State                                                  0
# Electric Vehicle Type                                  0
# dtype: int64

# %% [markdown]
# *NOTE: create a function to compare list indexes to make it more generalized*

# %%
# 1. look for common indexes
# 2. print them
# 3. drop them from the dataframe
# 4. show the rest nulls
# 5. drop the ones in 'Vehicle Location'

# %%
# Need to create a function to make easy
display(df[df['2020 Census Tract'].isnull()])
display(df[df['City'].isnull()])
display(df[df['Electric Utility'].isnull()])
display(df[df['Postal Code'].isnull()])
display(df[df['County'].isnull()])
# Out:
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 114     WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 148234  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 157590  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019      TESLA
# 175158  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model                   Electric Vehicle Type  \
# 114        530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148234  MODEL X          Battery Electric Vehicle (BEV)
# 157590  MODEL 3          Battery Electric Vehicle (BEV)
# 175158     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 114                Not eligible due to low battery range              16
# 148234           Clean Alternative Fuel Vehicle Eligible             200
# 157590           Clean Alternative Fuel Vehicle Eligible             220
# 175158           Clean Alternative Fuel Vehicle Eligible              53
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 114         53400                   NaN       244582593              NaN
# 148234          0                   NaN       159850029              NaN
# 157590          0                   NaN       475254825              NaN
# 175158          0                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 114                 NaN                NaN
# 148234              NaN                NaN
# 157590              NaN                NaN
# 175158              NaN                NaN
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 114     WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 148234  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 157590  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019      TESLA
# 175158  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model                   Electric Vehicle Type  \
# 114        530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148234  MODEL X          Battery Electric Vehicle (BEV)
# 157590  MODEL 3          Battery Electric Vehicle (BEV)
# 175158     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 114                Not eligible due to low battery range              16
# 148234           Clean Alternative Fuel Vehicle Eligible             200
# 157590           Clean Alternative Fuel Vehicle Eligible             220
# 175158           Clean Alternative Fuel Vehicle Eligible              53
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 114         53400                   NaN       244582593              NaN
# 148234          0                   NaN       159850029              NaN
# 157590          0                   NaN       475254825              NaN
# 175158          0                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 114                 NaN                NaN
# 148234              NaN                NaN
# 157590              NaN                NaN
# 175158              NaN                NaN
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 114     WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 148234  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 157590  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019      TESLA
# 175158  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model                   Electric Vehicle Type  \
# 114        530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148234  MODEL X          Battery Electric Vehicle (BEV)
# 157590  MODEL 3          Battery Electric Vehicle (BEV)
# 175158     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 114                Not eligible due to low battery range              16
# 148234           Clean Alternative Fuel Vehicle Eligible             200
# 157590           Clean Alternative Fuel Vehicle Eligible             220
# 175158           Clean Alternative Fuel Vehicle Eligible              53
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 114         53400                   NaN       244582593              NaN
# 148234          0                   NaN       159850029              NaN
# 157590          0                   NaN       475254825              NaN
# 175158          0                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 114                 NaN                NaN
# 148234              NaN                NaN
# 157590              NaN                NaN
# 175158              NaN                NaN
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 114     WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 148234  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 157590  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019      TESLA
# 175158  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model                   Electric Vehicle Type  \
# 114        530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148234  MODEL X          Battery Electric Vehicle (BEV)
# 157590  MODEL 3          Battery Electric Vehicle (BEV)
# 175158     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 114                Not eligible due to low battery range              16
# 148234           Clean Alternative Fuel Vehicle Eligible             200
# 157590           Clean Alternative Fuel Vehicle Eligible             220
# 175158           Clean Alternative Fuel Vehicle Eligible              53
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 114         53400                   NaN       244582593              NaN
# 148234          0                   NaN       159850029              NaN
# 157590          0                   NaN       475254825              NaN
# 175158          0                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 114                 NaN                NaN
# 148234              NaN                NaN
# 157590              NaN                NaN
# 175158              NaN                NaN
#         VIN (1-10) County City State  Postal Code  Model Year       Make  \
# 114     WBAJA9C50K    NaN  NaN    AE          NaN        2019        BMW
# 148234  5YJXCAE24H    NaN  NaN    BC          NaN        2017      TESLA
# 157590  5YJ3E1EA5K    NaN  NaN    BC          NaN        2019      TESLA
# 175158  1G1RB6S53J    NaN  NaN    BC          NaN        2018  CHEVROLET
#
#           Model                   Electric Vehicle Type  \
# 114        530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148234  MODEL X          Battery Electric Vehicle (BEV)
# 157590  MODEL 3          Battery Electric Vehicle (BEV)
# 175158     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 114                Not eligible due to low battery range              16
# 148234           Clean Alternative Fuel Vehicle Eligible             200
# 157590           Clean Alternative Fuel Vehicle Eligible             220
# 175158           Clean Alternative Fuel Vehicle Eligible              53
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 114         53400                   NaN       244582593              NaN
# 148234          0                   NaN       159850029              NaN
# 157590          0                   NaN       475254825              NaN
# 175158          0                   NaN       477613216              NaN
#
#        Electric Utility  2020 Census Tract
# 114                 NaN                NaN
# 148234              NaN                NaN
# 157590              NaN                NaN
# 175158              NaN                NaN

# %% [markdown]
# ### We have 4 common rows for missing vlaues of County, City, Postal Code, Legislative District, Vehicle Location, Electric Utility, 2020 Census Tract, hence considering to remove those rows as we can not impute any of these details as all are related and we dont have any of the values for reference. Comparing 4 rows to 200000 rows it will not impact the data hence removed.

# %%
df = df.dropna(subset=['County'])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Legislative District                                 438
# Vehicle Location                                       4
# VIN (1-10)                                             0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Utility                                       0
# DOL Vehicle ID                                         0
# Base MSRP                                              0
# Electric Range                                         0
# Electric Vehicle Type                                  0
# County                                                 0
# Model                                                  0
# Make                                                   0
# Model Year                                             0
# Postal Code                                            0
# State                                                  0
# City                                                   0
# 2020 Census Tract                                      0
# dtype: int64

# %%
df[df['Vehicle Location'].isnull()]
# Out:
#         VIN (1-10)   County        City State  Postal Code  Model Year  \
# 130378  KNDJX3AE8H  Pacific  Long Beach    WA      98634.0        2017
# 146036  KMHE54L2XH  Pacific  Long Beach    WA      98634.0        2017
# 181996  1C4JJXP69P  Pacific  Long Beach    WA      98634.0        2023
# 192143  1G1FW6S08N  Pacific  Long Beach    WA      98634.0        2022
#
#              Make     Model                   Electric Vehicle Type  \
# 130378        KIA   SOUL EV          Battery Electric Vehicle (BEV)
# 146036    HYUNDAI    SONATA  Plug-in Hybrid Electric Vehicle (PHEV)
# 181996       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 192143  CHEVROLET   BOLT EV          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 130378            Clean Alternative Fuel Vehicle Eligible              93
# 146036              Not eligible due to low battery range              27
# 181996              Not eligible due to low battery range              21
# 192143  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID Vehicle Location  \
# 130378      32250                  19.0       106442773              NaN
# 146036          0                  19.0       245533578              NaN
# 181996          0                  19.0       254934886              NaN
# 192143          0                  19.0       218102209              NaN
#
#                                          Electric Utility  2020 Census Tract
# 130378  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 146036  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 181996  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 192143  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10

# %%
df['Vehicle Location']
# Out:
# 0           POINT (-122.957046 46.991391)
# 1         POINT (-122.6530052 47.4739066)
# 2            POINT (-120.530331 46.59534)
# 3            POINT (-120.530331 46.59534)
# 4           POINT (-122.206146 47.839957)
#                        ...
# 200043    POINT (-122.0483457 47.9435765)
# 200044     POINT (-122.197791 47.0948565)
# 200045      POINT (-117.428902 47.658268)
# 200046      POINT (-122.306706 47.792043)
# 200047       POINT (-122.636245 47.62806)
# Name: Vehicle Location, Length: 200044, dtype: object

# %%
same_loc_VL=df[(df['County']=='Pacific') & (df['City']=='Long Beach')]
same_loc_VL
# Out:
#         VIN (1-10)   County        City State  Postal Code  Model Year  \
# 87908   5YJ3E1EB1J  Pacific  Long Beach    WA      98631.0        2018
# 90373   4JGDM4EB7P  Pacific  Long Beach    WA      98631.0        2023
# 94553   1G1FY6S09M  Pacific  Long Beach    WA      98631.0        2021
# 95761   5UX43EU05R  Pacific  Long Beach    WA      98631.0        2024
# 95786   JTMEB3FV6N  Pacific  Long Beach    WA      98631.0        2022
# 97072   5YJ3E1EB3J  Pacific  Long Beach    WA      98631.0        2018
# 97716   JTDKARFP9H  Pacific  Long Beach    WA      98631.0        2017
# 101354  KNDCS3LFXR  Pacific  Long Beach    WA      98631.0        2024
# 103056  1FTVW1EV5P  Pacific  Long Beach    WA      98631.0        2023
# 104744  JTDACACU5P  Pacific  Long Beach    WA      98631.0        2023
# 105185  5YJ3E1EA4J  Pacific  Long Beach    WA      98631.0        2018
# 106143  1G1FY6S05K  Pacific  Long Beach    WA      98631.0        2019
# 107031  1G1RC6S51J  Pacific  Long Beach    WA      98631.0        2018
# 107500  JTDACACU2R  Pacific  Long Beach    WA      98631.0        2024
# 107765  KNDCM3LD8L  Pacific  Long Beach    WA      98631.0        2020
# 108387  JTDKARFP9J  Pacific  Long Beach    WA      98631.0        2018
# 112658  WBY1Z2C51F  Pacific  Long Beach    WA      98631.0        2015
# 116243  KNDC3DLC1P  Pacific  Long Beach    WA      98631.0        2023
# 117433  KMUKEDTB4P  Pacific  Long Beach    WA      98631.0        2023
# 121251  5YJ3E1EA5J  Pacific  Long Beach    WA      98631.0        2018
# 122643  JTDKARFP8H  Pacific  Long Beach    WA      98631.0        2017
# 129242  KNDCR3LF3R  Pacific  Long Beach    WA      98631.0        2024
# 130378  KNDJX3AE8H  Pacific  Long Beach    WA      98634.0        2017
# 135716  7SAYGDEE5P  Pacific  Long Beach    WA      98631.0        2023
# 144370  5UXTA6C01N  Pacific  Long Beach    WA      98631.0        2022
# 145185  5YJYGDEE3M  Pacific  Long Beach    WA      98631.0        2021
# 145663  1G1FX6S02H  Pacific  Long Beach    WA      98631.0        2017
# 145944  1N4BZ1DP3L  Pacific  Long Beach    WA      98631.0        2020
# 146036  KMHE54L2XH  Pacific  Long Beach    WA      98634.0        2017
# 147683  1FTVW1EV8P  Pacific  Long Beach    WA      98631.0        2023
# 150709  5YJXCDE27H  Pacific  Long Beach    WA      98631.0        2017
# 154813  1FTVW1EL8N  Pacific  Long Beach    WA      98631.0        2022
# 157041  KNDCR3LF9P  Pacific  Long Beach    WA      98631.0        2023
# 158310  5YJ3E1EAXJ  Pacific  Long Beach    WA      98631.0        2018
# 166770  JTMAB3FV9M  Pacific  Long Beach    WA      98631.0        2021
# 167463  3FMTK3SU6M  Pacific  Long Beach    WA      98631.0        2021
# 168726  1N4AZ1BV8M  Pacific  Long Beach    WA      98631.0        2021
# 169631  3FMTK3SU5N  Pacific  Long Beach    WA      98631.0        2022
# 174591  3FMTK3S5XP  Pacific  Long Beach    WA      98631.0        2023
# 179069  JTMABACAXR  Pacific  Long Beach    WA      98631.0        2024
# 181078  1G1RA6E42C  Pacific  Long Beach    WA      98631.0        2012
# 181996  1C4JJXP69P  Pacific  Long Beach    WA      98634.0        2023
# 183497  WDC0G5EB9K  Pacific  Long Beach    WA      98631.0        2019
# 184693  JTDKN3DP7C  Pacific  Long Beach    WA      98631.0        2012
# 188838  1FTVW1EV9P  Pacific  Long Beach    WA      98631.0        2023
# 189099  KNDCR3L10R  Pacific  Long Beach    WA      98631.0        2024
# 189276  5YJ3E1EA3J  Pacific  Long Beach    WA      98631.0        2018
# 192143  1G1FW6S08N  Pacific  Long Beach    WA      98634.0        2022
# 196766  KNDC3DLC6R  Pacific  Long Beach    WA      98631.0        2024
# 196998  KNDCR3L16P  Pacific  Long Beach    WA      98631.0        2023
# 199460  LVYBC0AL3J  Pacific  Long Beach    WA      98631.0        2018
#
#                  Make           Model                   Electric Vehicle Type  \
# 87908           TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 90373   MERCEDES-BENZ   EQS-CLASS SUV          Battery Electric Vehicle (BEV)
# 94553       CHEVROLET         BOLT EV          Battery Electric Vehicle (BEV)
# 95761             BMW              X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 95786          TOYOTA      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 97072           TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 97716          TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 101354            KIA            NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 103056           FORD           F-150          Battery Electric Vehicle (BEV)
# 104744         TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 105185          TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 106143      CHEVROLET         BOLT EV          Battery Electric Vehicle (BEV)
# 107031      CHEVROLET            VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 107500         TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 107765            KIA            NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 108387         TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 112658            BMW              I3          Battery Electric Vehicle (BEV)
# 116243            KIA             EV6          Battery Electric Vehicle (BEV)
# 117433        GENESIS            GV60          Battery Electric Vehicle (BEV)
# 121251          TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 122643         TOYOTA     PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 129242            KIA            NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 130378            KIA         SOUL EV          Battery Electric Vehicle (BEV)
# 135716          TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 144370            BMW              X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 145185          TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 145663      CHEVROLET         BOLT EV          Battery Electric Vehicle (BEV)
# 145944         NISSAN            LEAF          Battery Electric Vehicle (BEV)
# 146036        HYUNDAI          SONATA  Plug-in Hybrid Electric Vehicle (PHEV)
# 147683           FORD           F-150          Battery Electric Vehicle (BEV)
# 150709          TESLA         MODEL X          Battery Electric Vehicle (BEV)
# 154813           FORD           F-150          Battery Electric Vehicle (BEV)
# 157041            KIA            NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 158310          TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 166770         TOYOTA      RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 167463           FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# 168726         NISSAN            LEAF          Battery Electric Vehicle (BEV)
# 169631           FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# 174591           FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# 179069         TOYOTA            BZ4X          Battery Electric Vehicle (BEV)
# 181078      CHEVROLET            VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 181996           JEEP        WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 183497  MERCEDES-BENZ       GLC-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 184693         TOYOTA   PRIUS PLUG-IN  Plug-in Hybrid Electric Vehicle (PHEV)
# 188838           FORD           F-150          Battery Electric Vehicle (BEV)
# 189099            KIA            NIRO          Battery Electric Vehicle (BEV)
# 189276          TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 192143      CHEVROLET         BOLT EV          Battery Electric Vehicle (BEV)
# 196766            KIA             EV6          Battery Electric Vehicle (BEV)
# 196998            KIA            NIRO          Battery Electric Vehicle (BEV)
# 199460          VOLVO             S90  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 87908             Clean Alternative Fuel Vehicle Eligible             215
# 90373   Eligibility unknown as battery range has not b...               0
# 94553   Eligibility unknown as battery range has not b...               0
# 95761             Clean Alternative Fuel Vehicle Eligible              39
# 95786             Clean Alternative Fuel Vehicle Eligible              42
# 97072             Clean Alternative Fuel Vehicle Eligible             215
# 97716               Not eligible due to low battery range              25
# 101354            Clean Alternative Fuel Vehicle Eligible              33
# 103056  Eligibility unknown as battery range has not b...               0
# 104744            Clean Alternative Fuel Vehicle Eligible              39
# 105185            Clean Alternative Fuel Vehicle Eligible             215
# 106143            Clean Alternative Fuel Vehicle Eligible             238
# 107031            Clean Alternative Fuel Vehicle Eligible              53
# 107500            Clean Alternative Fuel Vehicle Eligible              39
# 107765              Not eligible due to low battery range              26
# 108387              Not eligible due to low battery range              25
# 112658            Clean Alternative Fuel Vehicle Eligible              81
# 116243  Eligibility unknown as battery range has not b...               0
# 117433  Eligibility unknown as battery range has not b...               0
# 121251            Clean Alternative Fuel Vehicle Eligible             215
# 122643              Not eligible due to low battery range              25
# 129242            Clean Alternative Fuel Vehicle Eligible              33
# 130378            Clean Alternative Fuel Vehicle Eligible              93
# 135716  Eligibility unknown as battery range has not b...               0
# 144370            Clean Alternative Fuel Vehicle Eligible              30
# 145185  Eligibility unknown as battery range has not b...               0
# 145663            Clean Alternative Fuel Vehicle Eligible             238
# 145944            Clean Alternative Fuel Vehicle Eligible             215
# 146036              Not eligible due to low battery range              27
# 147683  Eligibility unknown as battery range has not b...               0
# 150709            Clean Alternative Fuel Vehicle Eligible             200
# 154813  Eligibility unknown as battery range has not b...               0
# 157041            Clean Alternative Fuel Vehicle Eligible              33
# 158310            Clean Alternative Fuel Vehicle Eligible             215
# 166770            Clean Alternative Fuel Vehicle Eligible              42
# 167463  Eligibility unknown as battery range has not b...               0
# 168726  Eligibility unknown as battery range has not b...               0
# 169631  Eligibility unknown as battery range has not b...               0
# 174591  Eligibility unknown as battery range has not b...               0
# 179069  Eligibility unknown as battery range has not b...               0
# 181078            Clean Alternative Fuel Vehicle Eligible              35
# 181996              Not eligible due to low battery range              21
# 183497              Not eligible due to low battery range              10
# 184693              Not eligible due to low battery range               6
# 188838  Eligibility unknown as battery range has not b...               0
# 189099  Eligibility unknown as battery range has not b...               0
# 189276            Clean Alternative Fuel Vehicle Eligible             215
# 192143  Eligibility unknown as battery range has not b...               0
# 196766  Eligibility unknown as battery range has not b...               0
# 196998  Eligibility unknown as battery range has not b...               0
# 199460              Not eligible due to low battery range              21
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 87908           0                  19.0       474549659
# 90373           0                  19.0       265033443
# 94553           0                  19.0       148912977
# 95761           0                  19.0       266823805
# 95786           0                  19.0       238265933
# 97072           0                  19.0       288967899
# 97716           0                  19.0       349768415
# 101354          0                  19.0       264294033
# 103056          0                  19.0       261600839
# 104744          0                  19.0       265104759
# 105185          0                  19.0       249919099
# 106143          0                  19.0       476824792
# 107031          0                  19.0       124409946
# 107500          0                  19.0       263105342
# 107765          0                  19.0       182261509
# 108387          0                  19.0       475228715
# 112658          0                  19.0       268006672
# 116243          0                  19.0       253636400
# 117433          0                  19.0       241643958
# 121251          0                  19.0       107042694
# 122643          0                  19.0       230303349
# 129242          0                  19.0       269661836
# 130378      32250                  19.0       106442773
# 135716          0                  19.0       225728891
# 144370          0                  19.0       193646463
# 145185          0                  19.0       176337346
# 145663          0                  19.0       260917058
# 145944          0                  19.0       196680494
# 146036          0                  19.0       245533578
# 147683          0                  19.0       244226398
# 150709          0                  19.0       476291406
# 154813          0                  19.0       229416708
# 157041          0                  19.0       235897840
# 158310          0                  19.0       263264578
# 166770          0                  19.0       178965811
# 167463          0                  19.0       187021726
# 168726          0                  19.0       175109875
# 169631          0                  19.0       228237488
# 174591          0                  19.0       265949974
# 179069          0                  19.0       269416241
# 181078          0                  19.0       123027628
# 181996          0                  19.0       254934886
# 183497          0                  19.0       100717746
# 184693          0                  19.0       264432003
# 188838          0                  19.0       264652083
# 189099          0                  19.0       262852327
# 189276          0                  19.0       258012639
# 192143          0                  19.0       218102209
# 196766          0                  19.0       267447624
# 196998          0                  19.0       260465908
# 199460          0                  19.0       182895576
#
#                      Vehicle Location  \
# 87908   POINT (-124.035084 46.375408)
# 90373   POINT (-124.035084 46.375408)
# 94553   POINT (-124.035084 46.375408)
# 95761   POINT (-124.035084 46.375408)
# 95786   POINT (-124.035084 46.375408)
# 97072   POINT (-124.035084 46.375408)
# 97716   POINT (-124.035084 46.375408)
# 101354  POINT (-124.035084 46.375408)
# 103056  POINT (-124.035084 46.375408)
# 104744  POINT (-124.035084 46.375408)
# 105185  POINT (-124.035084 46.375408)
# 106143  POINT (-124.035084 46.375408)
# 107031  POINT (-124.035084 46.375408)
# 107500  POINT (-124.035084 46.375408)
# 107765  POINT (-124.035084 46.375408)
# 108387  POINT (-124.035084 46.375408)
# 112658  POINT (-124.035084 46.375408)
# 116243  POINT (-124.035084 46.375408)
# 117433  POINT (-124.035084 46.375408)
# 121251  POINT (-124.035084 46.375408)
# 122643  POINT (-124.035084 46.375408)
# 129242  POINT (-124.035084 46.375408)
# 130378                            NaN
# 135716  POINT (-124.035084 46.375408)
# 144370  POINT (-124.035084 46.375408)
# 145185  POINT (-124.035084 46.375408)
# 145663  POINT (-124.035084 46.375408)
# 145944  POINT (-124.035084 46.375408)
# 146036                            NaN
# 147683  POINT (-124.035084 46.375408)
# 150709  POINT (-124.035084 46.375408)
# 154813  POINT (-124.035084 46.375408)
# 157041  POINT (-124.035084 46.375408)
# 158310  POINT (-124.035084 46.375408)
# 166770  POINT (-124.035084 46.375408)
# 167463  POINT (-124.035084 46.375408)
# 168726  POINT (-124.035084 46.375408)
# 169631  POINT (-124.035084 46.375408)
# 174591  POINT (-124.035084 46.375408)
# 179069  POINT (-124.035084 46.375408)
# 181078  POINT (-124.035084 46.375408)
# 181996                            NaN
# 183497  POINT (-124.035084 46.375408)
# 184693  POINT (-124.035084 46.375408)
# 188838  POINT (-124.035084 46.375408)
# 189099  POINT (-124.035084 46.375408)
# 189276  POINT (-124.035084 46.375408)
# 192143                            NaN
# 196766  POINT (-124.035084 46.375408)
# 196998  POINT (-124.035084 46.375408)
# 199460  POINT (-124.035084 46.375408)
#
#                                          Electric Utility  2020 Census Tract
# 87908   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 90373   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 94553   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 95761   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 95786   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 97072   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 97716   BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 101354  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 103056  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 104744  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 105185  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 106143  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 107031  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 107500  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 107765  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 108387  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 112658  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 116243  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 117433  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 121251  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 122643  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 129242  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 130378  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 135716  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 144370  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 145185  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 145663  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 145944  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 146036  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 147683  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 150709  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 154813  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 157041  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 158310  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 166770  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 167463  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 168726  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 169631  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 174591  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 179069  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 181078  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 181996  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 183497  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 184693  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 188838  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 189099  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 189276  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 192143  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 196766  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 196998  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10
# 199460  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       5.304995e+10

# %%
Vl_rep_val=same_loc_VL['Vehicle Location'].unique()
Vl_rep_val=Vl_rep_val[0]
Vl_rep_val

# %% [markdown]
# ### As per analysis we see all the rows having same values of Vehicle Location like for County, City leads to same Vehicle Location for the cells having null. Hence Imputing the Common Vechile Location using fillna().

# %%
df['Vehicle Location']=df['Vehicle Location'].fillna(Vl_rep_val)

# %%
df.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Analysis of Legislative District missing values

# %%
df[df['Legislative District'].isnull()]

# %%
df.head()

# %% [markdown]
# ## As per the analysis of head i.e. first 5 rows our assumption of the correlation of County, City and States to Legislative District fails. As we see no dependeny or relation of Legislative District nto any of these columns.
#
# ### We recomend to impute using KNN as the column may be based on these other columns indirecly. We are not using mean and median as it might affect variance and also the data is categotical. Mode can be used but it will somehow incline or bias the data towards the value of mode.

# %%
knn_features = ["County", "City", "Postal Code"]
df_knn = df.copy()

# Encoding categorical variables as numbers
label_encoders = {}
for col in ["County", "City"]:
    le = LabelEncoder()
    df_knn[col] = le.fit_transform(df_knn[col].astype(str))
    label_encoders[col] = le

# Converting Legislative District to numeric (for imputation)
df_knn["Legislative District"] = pd.to_numeric(df_knn["Legislative District"], errors='coerce')

# Applying KNN Imputer
knn_imputer = KNNImputer(n_neighbors=5, weights="uniform")
df_knn[["Legislative District"]] = knn_imputer.fit_transform(df_knn[["Legislative District"]])

# Converting back to integer
df_knn["Legislative District"] = df_knn["Legislative District"].round().astype(int)

# %%
df['Legislative District']=df_knn["Legislative District"]
display(df["Legislative District"].isnull())
# Out:
# C:\Users\ranro\AppData\Local\Temp\ipykernel_33996\780317215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Legislative District']=df_knn["Legislative District"]
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 200043    False
# 200044    False
# 200045    False
# 200046    False
# 200047    False
# Name: Legislative District, Length: 200044, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200044 entries, 0 to 200047
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         200044 non-null  object
#  1   County                                             200044 non-null  object
#  2   City                                               200044 non-null  object
#  3   State                                              200044 non-null  object
#  4   Postal Code                                        200044 non-null  float64
#  5   Model Year                                         200044 non-null  int64
#  6   Make                                               200044 non-null  object
#  7   Model                                              200044 non-null  object
#  8   Electric Vehicle Type                              200044 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  200044 non-null  object
#  10  Electric Range                                     200044 non-null  int64
#  11  Base MSRP                                          200044 non-null  int64
#  12  Legislative District                               200044 non-null  int32
#  13  DOL Vehicle ID                                     200044 non-null  int64
#  14  Vehicle Location                                   200040 non-null  object
#  15  Electric Utility                                   200044 non-null  object
#  16  2020 Census Tract                                  200044 non-null  float64
# dtypes: float64(2), int32(1), int64(4), object(10)
# memory usage: 26.7+ MB

# %%
df['Postal Code']=df['Postal Code'].astype(int).astype(str)
# Out:
# C:\Users\ranro\AppData\Local\Temp\ipykernel_33996\655318355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Postal Code']=df['Postal Code'].astype(int).astype(str)

# %%
df.duplicated().count_value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33996\1644427437.py in ?()
# ----> 1 df.duplicated().count_value()
#
# c:\Users\ranro\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'count_value'

# %% [markdown]
# ### Step 4.2
# ### Handle Outliers:
# Detect Outliers: Use visualizations (e.g., box plots) or statistical methods (e.g., Z-scores) to identify outliers.
# <br>Treat Outliers: Depending on the context, either remove, transform, or cap outliers.

# %%
df.plot(kind='box', subplots=True)
plt.figure(figsize=(10,20))
plt.suptitle('Boxplot of numerical columns', x=1, y=1, ha='center', fontsize='large')
plt.tight_layout()
plt.show()

# %%
numerical_df = df.select_dtypes(include=['number'])
numerical_featrues = numerical_df.columns
numerical_df.info()

# Check Z-Score for outliers
def z_score_analysis(df, threshold=3):
    z_scores = zscore(df)
    abs_z_scores = np.abs(z_scores)
    filtered_entries = (abs_z_scores < threshold).all(axis=1)
    outliers_df = df[~filtered_entries]
    return outliers_df

# Check outliers for different thresholds
for threshold in [2, 2.5, 3]:
    outliers_df = z_score_analysis(numerical_df, threshold)
    num_of_outliers = outliers_df.shape[0]
    print(f'Outliers for threshold {threshold}: {num_of_outliers}, {(num_of_outliers/len(df))*100:.2f}%')
    print(f'outliers_df shape: {outliers_df.shape}')
    print(f'df shape: {df.shape}\n')
    display(outliers_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200044 entries, 0 to 200047
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Model Year            200044 non-null  int64
#  1   Electric Range        200044 non-null  int64
#  2   Base MSRP             200044 non-null  int64
#  3   Legislative District  200044 non-null  int32
#  4   DOL Vehicle ID        200044 non-null  int64
#  5   2020 Census Tract     200044 non-null  float64
# dtypes: float64(1), int32(1), int64(4)
# memory usage: 9.9 MB
# Outliers for threshold 2: 34765, 17.38%
# outliers_df shape: (34765, 6)
# df shape: (200044, 17)
#         Model Year  Electric Range  Base MSRP  Legislative District  \
# 5             2014              72          0                    14
# 6             2012             265      59900                    22
# 9             2017              84          0                    43
# 11            2014             208      69900                     1
# 12            2020             291          0                    44
# ...            ...             ...        ...                   ...
# 200018        2020             322          0                     5
# 200019        2012              73          0                    11
# 200021        2019             289          0                     1
# 200038        2020             322          0                    41
# 200046        2014              38          0                    32
#
#         DOL Vehicle ID  2020 Census Tract
# 5              8045817       5.307700e+10
# 6            188634442       5.306701e+10
# 9              9411349       5.303300e+10
# 11           225773271       5.306105e+10
# 12           121781950       5.306104e+10
# ...                ...                ...
# 200018         5010883       5.303303e+10
# 200019       250994733       5.303301e+10
# 200021       221517068       5.306105e+10
# 200038         2107171       5.303303e+10
# 200046       170747377       5.306105e+10
#
# [34765 rows x 6 columns]
# Outliers for threshold 2.5: 24182, 12.09%
# outliers_df shape: (24182, 6)
# df shape: (200044, 17)
#         Model Year  Electric Range  Base MSRP  Legislative District  \
# 5             2014              72          0                    14
# 6             2012             265      59900                    22
# 9             2017              84          0                    43
# 11            2014             208      69900                     1
# 12            2020             291          0                    44
# ...            ...             ...        ...                   ...
# 200004        2020             308          0                    45
# 200018        2020             322          0                     5
# 200019        2012              73          0                    11
# 200021        2019             289          0                     1
# 200038        2020             322          0                    41
#
#         DOL Vehicle ID  2020 Census Tract
# 5              8045817       5.307700e+10
# 6            188634442       5.306701e+10
# 9              9411349       5.303300e+10
# 11           225773271       5.306105e+10
# 12           121781950       5.306104e+10
# ...                ...                ...
# 200004       128553386       5.303303e+10
# 200018         5010883       5.303303e+10
# 200019       250994733       5.303301e+10
# 200021       221517068       5.306105e+10
# 200038         2107171       5.303303e+10
#
# [24182 rows x 6 columns]
# Outliers for threshold 3: 14869, 7.43%
# outliers_df shape: (14869, 6)
# df shape: (200044, 17)
#         Model Year  Electric Range  Base MSRP  Legislative District  \
# 6             2012             265      59900                    22
# 11            2014             208      69900                     1
# 21            2018             215          0                     5
# 24            2020             266          0                    23
# 25            2018             151          0                     1
# ...            ...             ...        ...                   ...
# 199966        2014             208      69900                    31
# 199986        2020             322          0                    19
# 199994        2019              53          0                    27
# 200018        2020             322          0                     5
# 200038        2020             322          0                    41
#
#         DOL Vehicle ID  2020 Census Tract
# 6            188634442       5.306701e+10
# 11           225773271       5.306105e+10
# 21           475802505       5.303303e+10
# 24             2254542       5.303509e+10
# 25           476219747       5.306105e+10
# ...                ...                ...
# 199966       306854019       5.305394e+10
# 199986       127133681       5.302700e+10
# 199994       478887076       5.305306e+10
# 200018         5010883       5.303303e+10
# 200038         2107171       5.303303e+10
#
# [14869 rows x 6 columns]

# %% [markdown]
# ### Step 4.3
# ### Correct Data Types:
# Ensure that each feature has the correct data type (e.g.,convert columns to categorical, datetime, etc.).

# %% [markdown]
# ### Step 4.4
# ### Handle Duplicates:
# Check for and remove duplicate records.

# %%
df.duplicated().sum()

# %% [markdown]
# ## Step 5
# ## Univariate Analysis

# %% [markdown]
# ### Step 5.1
# Summary Statistics: Review measures of central tendency (mean, median) and dispersion (standard deviation, variance).

# %% [markdown]
# ### Step 5.2
# Visualize Distributions: Use histograms, box plots, and bar charts to understand the distribution of individual variables.

# %% [markdown]
# ## Step 6
# ## Bivariate Analysis

# %% [markdown]
# ### Step 6.1
# Correlation Analysis: Calculate correlation coefficients (e.g., Pearson, Spearman) to understand relationships between numerical variables.

# %% [markdown]
# ### Step 6.2
# Cross-tabulation: Analyze relationships between categorical variables using crosstabs.

# %% [markdown]
# ### STEP 6.3
# Visualize Relationships:
# Scatter Plots: For numerical variables.
# Box Plots and Violin Plots: To compare distributions across categories.
# Heatmaps: To visualize correlations.

# %% [markdown]
# ## Step 7
# ## Multivariate Analysis

# %% [markdown]
# ### Step 7.1
# Pairplot/Scatterplot Matrix: Use to visualize relationships between multiple numerical variables.

# %% [markdown]
# ### Step 7.2
# Multivariate Statistics: Explore techniques like Principal Component Analysis (PCA) for dimensionality reduction.

# %% [markdown]
# ### Step 7.3
# Advanced Visualizations: Consider using more complex visualizations like pairwise correlation heatmaps or 3D plots.

# %% [markdown]
# ## Step 8
# ## Feature Engineering

# %% [markdown]
# ### Step 8.1
# Create New Features: Based on domain knowledge or interaction terms.

# %% [markdown]
# ### Step 8.2
# Feature Transformation: Normalize or standardize features, apply log transformations, etc.

# %% [markdown]
# ### Step 8.3
# Encoding Categorical Variables: Convert categorical variables to numerical using techniques like one-hot encoding, label encoding, or frequency encoding.
